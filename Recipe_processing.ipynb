# %%
import json
import re
import sqlite3
import numpy as np
import pandas as pd
import sqlite3
#import spacy

# %%
# Cycle through the json file and grab a certain amount of recipes; limit the number because the file is +100MB
data = []
counter = 0 
with open("20170107-061401-recipeitems.json", encoding = 'utf-8') as json_file:
    # It's neccessary to use readlines(), otherwise the data doesn't come out as lines and can't be read as a json type
    for line in json_file.readlines():
        data.append(json.loads(line))
        counter+= 1
        if counter > 100000:
            break

# %%
def parse_ingredients(recipe_name, ingredients_list):
    # Use regex to find the patterns for quantity and then the following ingredient stuff; the patterns for quantities look like:
    # ##, #/#, #-#/#; also, remove full stops as this breaks matching and remove everything between () a it's superfluous
    # Parameters: dictionary of recipe_name: [ingredients]
    # Returns a dict of {Name: {Ingredient[n]: "ingredient", measure[n]: measure(s)}
    
    n = 0 
    recipe_ingredients = {}
    
    for item in ingredients_list:
        item = re.sub(" \(.*\)", "", item)
        item = re.sub("[.]", "", item)
        quantity_pattern = re.compile("([0-9][0-9]*/*-*[0-9]*/*[0-9]* \w+)")
        ingredient_quantity = re.findall(quantity_pattern, item)
        # Check if there is a number for the ingredient quanity, if not, work around it
        if len(ingredient_quantity) > 0:
        # The ingredient follows after the quantity, so look there for it
            ingredient_pattern = re.compile(str(ingredient_quantity[-1]+" (.*)"))
            ingredient = ingredient_pattern.search(item)
            # Everything is lower-case for consistency
            recipe_ingredients[str(n)+"_quanitity"] = ' '.join(ingredient_quantity).lower()
            if ingredient is not None:
                recipe_ingredients[str(n)+"_ingredient"] = ingredient[1].lower()
        else:
            recipe_ingredients[str(n)+"_quanitity"] = ' '.join(ingredient_quantity).lower()
            recipe_ingredients[str(n)+"_ingredient"] = item.lower()
        n += 1
    # A very small minority of the items have over 50 ingredients; remove these as this is a data processing error 
    # as these are likely a selection of recipes and including them creates an enormous, sparse table
    if n > 50:
        recipe_ingredients = None
    return recipe_ingredients

# %%
# Take the recipe name and ingredients and store those as key:val pairs
recipes = {}
ingredient_dict = {}
for item in data:
    # Ingredients are separated by newline and some have an extra space at the beginning; remove \n and 'of' as well
    ingredients = item['ingredients'].split('\n')
    ingredients = [re.sub(" of "," ", i.strip()) for i in ingredients]
    ingredient_dict[item['name']] = parse_ingredients(item['name'], ingredients)

# %%
recipes_df = np.transpose(pd.DataFrame(ingredient_dict))
#recipes_df.index.name = "Recipe_name"
#recipes_df.set_index(pd.Index(range(len(ingredient_dict.keys()))), inplace=True)
recipes_df.reset_index(inplace = True)
recipes_df.rename(columns={"index":"Recipe_name"}, inplace = True)
recipes_df = recipes_df.replace(np.nan, '', regex=True)
# Out:
#                           Recipe_name    0_ingredient        0_quanitity  \
# 0     Drop Biscuits and Sausage Gravy          3 cups      3 cups 3 cups
# 1           Hot Roast Beef Sandwiches        12 whole  12 whole 12 whole
# 2  Morrocan Carrot and Chickpea Salad       dressing:
# 3               Mixed Berry Shortcake          3 cups      3 cups 3 cups
# 4             Pomegranate Yogurt Bowl  for each bowl:
#
#       10_ingredient  10_quanitity  \
# 0
# 1
# 2  fresh mint, torn  1/3 cup 30 g
# 3             1 cup   1 cup 1 cup
# 4
#
#                                        11_ingredient 11_quanitity  \
# 0
# 1
# 2  for serving: lots toasted almond slices, dried...
# 3                                      ½ cups ½ cups
# 4
#
#    12_ingredient                 12_quanitity 13_ingredient  ...  \
# 0                                                            ...
# 1                                                            ...
# 2                                                            ...
# 3  2 tablespoons  2 tablespoons 2 tablespoons                ...
# 4                                                            ...
#
#                          5_ingredient                5_quanitity  \
# 0                             1 pound            1 pound 1 pound
# 1                        1 tablespoon  1 tablespoon 1 tablespoon
# 2   fine sea salt, plus more to taste               1/2 teaspoon
# 3                     1-¼ cup 1-¼ cup
# 4  sprinkling toasted sunflower seeds
#
#                                         6_ingredient  \
# 0                                      ⅓ cups ⅓ cups
# 1                                       1 tablespoon
# 2                                     cayenne pepper
# 3                            ½ teaspoons ½ teaspoons
# 4  optional: whole pomegranate seeds or fresh/dri...
#
#                  6_quanitity  \
# 0
# 1  1 tablespoon 1 tablespoon
# 2               1/8 teaspoon
# 3
# 4
#
#                                         7_ingredient  \
# 0                                             4 cups
# 1                                       1 tablespoon
# 2  carrots, shredded on a box grater or sliced wh...
# 3                                            2 pints
# 4
#
#                  7_quanitity             8_ingredient 8_quanitity  \
# 0              4 cups 4 cups  ½ teaspoons ½ teaspoons
# 1  1 tablespoon 1 tablespoon
# 2                  10 ounces         cooked chickpeas      2 cups
# 3            2 pints 2 pints            ⅓ cups ⅓ cups
# 4
#
#                                         9_ingredient              9_quanitity
# 0                                        2 teaspoons  2 teaspoons 2 teaspoons
# 1
# 2   dried pluots, plums, or dates cut into chickp...            2/3 cup 100 g
# 3                                          1 package      1 package 1 package
# 4
#
# [5 rows x 101 columns]

# %%
recipes_df.tail()
# Out:
#                   Recipe_name                            0_ingredient  \
# 89344        Crawfish Chowder                                  butter
# 89345          Crawfish Cakes                                     egg
# 89346         Crawfish Bisque                                  butter
# 89347      Crawfish Boulettes  cooked and peeled whole crawfish tails
# 89348  Crawfish and Corn Soup                                  butter
#
#          0_quanitity          10_ingredient   10_quanitity  \
# 89344        1/4 cup
# 89345       1 beaten
# 89346  6 tablespoons
# 89347      1 package  chopped fresh parsley  2 tablespoons
# 89348        1/2 cup           pepper sauce         1 dash
#
#                     11_ingredient   11_quanitity     12_ingredient  \
# 89344
# 89345
# 89346
# 89347  thinly sliced green onions  3 tablespoons
# 89348               salt to taste                 crawfish, peeled
#
#       12_quanitity             13_ingredient  ...  \
# 89344                                         ...
# 89345                                         ...
# 89346                                         ...
# 89347               vegetable oil for frying  ...
# 89348      1 pound                            ...
#
#                                  5_ingredient 5_quanitity  \
# 89344           condensed cream mushroom soup       1 can
# 89345  cooked and peeled whole crawfish tails     1 pound
# 89346                                    salt  1 teaspoon
# 89347     stale white bread, torn into pieces    5 slices
# 89348                        cream-style corn      2 cans
#
#                           6_ingredient   6_quanitity  \
# 89344       whole kernel corn, drained         1 can
# 89345  buttery round crackers, crushed      1 sleeve
# 89346            peeled crawfish tails  1 1 2 pounds
# 89347                                          1 egg
# 89348                whole kernel corn         1 can
#
#                       7_ingredient 7_quanitity                 8_ingredient  \
# 89344       cream cheese, softened    4 ounces          half-and-half cream
# 89345                   canola oil     1/4 cup
# 89346         worcestershire sauce  1 teaspoon  cayenne pepper, or to taste
# 89347                         salt  1 teaspoon                 black pepper
# 89348  condensed cream potato soup       1 can             creole seasoning
#
#         8_quanitity          9_ingredient   9_quanitity
# 89344        2 cups        cayenne pepper  1/2 teaspoon
# 89345
# 89346       1 pinch
# 89347  1/2 teaspoon       cajun seasoning   2 teaspoons
# 89348  1/4 teaspoon  worcestershire sauce  1/2 teaspoon
#
# [5 rows x 101 columns]

# %%
# Import SQLAlchemy and load the recipes into a DB for processing by the bot
from sqlalchemy import create_engine
from sqlalchemy import *
engine = create_engine("sqlite:///C:\\Users\\User\\Documents\\Python Scripts\\Recipes\\recipes.db", echo = False)

# %%
recipes_df.to_sql('recipes', con = engine, if_exists='append')

# %%
connection = engine.connect()
metadata = MetaData()
test_db = Table('recipes', metadata, autoload = True, autoload_with = engine)

# %%
print(test_db.columns.keys())
# Out:
# ['index', 'Recipe_name', '0_ingredient', '0_quanitity', '10_ingredient', '10_quanitity', '11_ingredient', '11_quanitity', '12_ingredient', '12_quanitity', '13_ingredient', '13_quanitity', '14_ingredient', '14_quanitity', '15_ingredient', '15_quanitity', '16_ingredient', '16_quanitity', '1_ingredient', '1_quanitity', '2_ingredient', '2_quanitity', '3_ingredient', '3_quanitity', '4_ingredient', '4_quanitity', '5_ingredient', '5_quanitity', '6_ingredient', '6_quanitity', '7_ingredient', '7_quanitity', '8_ingredient', '8_quanitity', '9_ingredient', '9_quanitity']

# %%
recipes_df[recipes_df["50_ingredient"] != ""]
# Out:
#                                              Recipe_name  \
# 1715   Roasted breast of duck with heart stew, gizzar...
# 2228   Pigeon wrapped in filo pastry with Parma ham, ...
# 2939   English vegetable minestrone with roasted chum...
# 3010           Tiffin: a selection of Indian street food
# 3012   Slow-roasted lamb shoulder with cashew nut and...
# 3031    Rosemary-smoked pigeon with apricots and almonds
# 3228                            Traditional Wedding Cake
# 3516   Slow poached chicken, sweetcorn egg, spinach w...
# 3792                 Venison Wellington with spring peas
# 3956                     Traditional spring wedding cake
# 4596      Creamed oysters wrapped in marinated sea trout
# 4644                                 Strawberry textures
# 4645   Wild rabbit with ham hock, carrots, asparagus ...
# 4646   Salad of Aberdeen Angus beef, carrots, horsera...
# 4674   Breasts of wild duck, warm duck brawn and a sm...
# 4687   Cornish mackerel with oysters, mussels, winkle...
# 4793         Cornish duck pancakes with duck scotch eggs
# 4794                Great British pork: from head to toe
# 5045           Rabbit with summer vegetables and truffle
# 5135   Hog's pudding with seaweed, potato terrine and...
# 5144   Rose veal steak and kidney pie with a piccalil...
# 5438                                The Bunny Pentathlon
# 5442                    Pen-y-Wyrlod lamb with umble pie
# 5513   Slow-cooked pork belly and pork cheeks with qu...
# 6213   Stuffed saddle of suckling pig, smoky pomme pu...
# 6386                                    Tri-city sliders
# 6393   Pork pie, mash and liquor, Scotch egg, pub atm...
# 6533   Malai kofta, aromatic rice, puris and cucumber...
# 6536         Stuffed peppers with potato bonda and salad
# 6844   Roast Mortimer Forest venison loin with bitter...
# 7060                              Chicken Biryani Recipe
# 61747               Cooking For Others: Baked Pasta Bash
# 62637       Potato-Pea Masala with Cilantro-Mint Chutney
# 63267                         Easy homemade curry pastes
# 63335  Baked Eggs &amp; Coffee Cake BrunchBaked Eggs ...
# 63814  Cooking For Others: BGSK’s Spring Break Blowou...
# 63853          Cooking For Others: Partner, Meet Partner
# 64019             Cooking For Others: Red Wine Reduction
# 64044       Cooking For Others: 24 Candles, 48 Meatballs
# 64117     Cooking For Others: 25 Years of Jor, 1 of BGSK
# 64179  Cooking for Others: Sunday Supper with Sister ...
# 64943               Potluck Parties: Magazine Club March
# 65037    Cooking For Others: Fish, Chips, and a Farewell
#
#                                    0_ingredient      0_quanitity  \
# 1715                                      ducks          2 small
# 2228                                    pigeons              4 x
# 2939                       100g/3½oz fresh peas
# 3010       drumsticks, flesh scored to the bone       12 chicken
# 3012                        mashed green papaya           2 tbsp
# 3031                    100g/3½oz fresh almonds
# 3228                    white sugar paste icing        2 lb 4 oz
# 3516             850g/1lb 14oz tinned sweetcorn
# 3792                 300g/10½oz unsalted butter
# 3956                    white sugar paste icing             4 oz
# 4596                        400g/14oz sea trout
# 4644                      100g/4oz caster sugar
# 4645                           500g/1lb 1oz ham              1 x
# 4646                        100ml/3½fl oz water
# 4674                                       duck           4 wild
# 4687                        300g/10½oz mackerel              3 x
# 4793                                                     1 onion
# 4794                        or conference pears       6 williams
# 5045                                    rabbits          2 whole
# 5135                                   sausages           2 pork
# 5144                  groundnut oil, for frying
# 5438                                                    2 garlic
# 5442                     14kg/3lb lamb shoulder              1 x
# 5513                       600ml/1½ pints water
# 6213                250ml/9fl oz dry white wine
# 6386                              konbu seaweed          1 sheet
# 6393            25g/1oz dried porcini mushrooms
# 6533                           1cm/½in cinnamon
# 6536                    handful fresh coriander
# 6844                       300g/10oz cocoa nibs
# 7060                       chicken(whole) = 1kg
# 61747                      matt’s birthday bash
# 62637                                    pieces     3 lbs 1 inch
# 63267                                    garlic         2 cloves
# 63335                                 olive oil  2-3 tablespoons
# 63814  bulbs, trimmed, halved and thinly sliced         2 fennel
# 63853                       a breakfast meeting
# 64019                             dish for dion
# 64044                             onion, grated          1 large
# 64117                                    phoebe
# 64179                             sunday supper
# 64943                              fresh greens         3-4 cups
# 65037                mahi mahi, cut into strips             1 lb
#
#                    100_ingredient 100_quanitity  \
# 1715
# 2228
# 2939
# 3010                                  14 litres
# 3012   small handful curry leaves
# 3031
# 3228
# 3516
# 3792
# 3956
# 4596
# 4644
# 4645
# 4646
# 4674
# 4687
# 4793
# 4794
# 5045
# 5135
# 5144
# 5438
# 5442
# 5513
# 6213
# 6386
# 6393
# 6533
# 6536
# 6844
# 7060
# 61747
# 62637
# 63267
# 63335
# 63814
# 63853
# 64019
# 64044
# 64117
# 64179
# 64943
# 65037
#
#                                   101_ingredient 101_quanitity 102_ingredient  \
# 1715
# 2228
# 2939
# 3010                               white vinegar        2 tbsp      olive oil
# 3012                                                   3 limes
# 3031
# 3228
# 3516
# 3792
# 3956
# 4596
# 4644
# 4645
# 4646
# 4674
# 4687
# 4793
# 4794
# 5045
# 5135
# 5144
# 5438
# 5442
# 5513
# 6213
# 6386
# 6393
# 6533
# 6536
# 6844
# 7060
# 61747
# 62637
# 63267
# 63335
# 63814
# 63853
# 64019
# 64044
# 64117  dried grated unsweetened coconut, toasted       2/3 cup
# 64179
# 64943
# 65037
#
#       102_quanitity 103_quanitity  ... 96_ingredient 96_quanitity  \
# 1715                               ...
# 2228                               ...
# 2939                               ...
# 3010         2 tbsp       1 onion  ...                     1 free
# 3012       3 lemons                ...        butter       2 tbsp
# 3031                               ...
# 3228                               ...
# 3516                               ...
# 3792                               ...
# 3956                               ...
# 4596                               ...
# 4644                               ...
# 4645                               ...
# 4646                               ...
# 4674                               ...
# 4687                               ...
# 4793                               ...
# 4794                               ...
# 5045                               ...
# 5135                               ...
# 5144                               ...
# 5438                               ...
# 5442                               ...
# 5513                               ...
# 6213                               ...
# 6386                               ...
# 6393                               ...
# 6533                               ...
# 6536                               ...
# 6844                               ...
# 7060                               ...
# 61747                              ...
# 62637                              ...
# 63267                              ...
# 63335                              ...
# 63814                              ...
# 63853                              ...
# 64019                              ...
# 64044                              ...
# 64117                     1 lemon  ...
# 64179                              ...
# 64943                              ...
# 65037                              ...
#
#       97_ingredient 97_quanitity        98_ingredient 98_quanitity  \
# 1715
# 2228
# 2939
# 3010     gram flour       2 tbsp            cornflour       1 tbsp
# 3012                 30 shallots  drizzle clear honey
# 3031
# 3228
# 3516
# 3792
# 3956
# 4596
# 4644
# 4645
# 4646
# 4674
# 4687
# 4793
# 4794
# 5045
# 5135
# 5144
# 5438
# 5442
# 5513
# 6213
# 6386
# 6393
# 6533
# 6536
# 6844
# 7060
# 61747
# 62637
# 63267
# 63335
# 63814
# 63853
# 64019
# 64044
# 64117   frozen peas       2 cups
# 64179
# 64943
# 65037
#
#                99_ingredient 99_quanitity  \
# 1715
# 2228
# 2939
# 3010   , for frying corn oil
# 3012   , for frying corn oil
# 3031
# 3228
# 3516
# 3792
# 3956
# 4596
# 4644
# 4645
# 4646
# 4674
# 4687
# 4793
# 4794
# 5045
# 5135
# 5144
# 5438
# 5442
# 5513
# 6213
# 6386
# 6393
# 6533
# 6536
# 6844
# 7060
# 61747
# 62637
# 63267
# 63335
# 63814
# 63853
# 64019
# 64044
# 64117         golden raisins        1 cup
# 64179
# 64943
# 65037
#
#                                9_ingredient    9_quanitity
# 1715                                               1 litre
# 2228                 500ml/18fl oz red wine
# 2939                           rapeseed oil       1-2 tbsp
# 3010                    ½ tsp ground ginger
# 3012                           garam masala          1 tsp
# 3031                                              1 garlic
# 3228                        ground cinnamon          2 tsp
# 3516                            fresh thyme       4 sprigs
# 3792           finely chopped fresh parsley         1 tbsp
# 3956                           cocoa powder         2 tbsp
# 4596       100ml/3½fl oz white wine vinegar
# 4644             60g/2¼fl oz liquid glucose
# 4645                             bay leaves        2 fresh
# 4646                                              1 orange
# 4674          25g/1oz finely chopped carrot
# 4687                           pinch celery
# 4793                                  anise         3 star
# 4794               13kg/3lb pork tenderloin
# 5045                   knob unsalted butter
# 5135                                              2 garlic
# 5144   salt and freshly ground black pepper
# 5438                                              4 rabbit
# 5442                        unsalted butter         1 tbsp
# 5513                                                8 pigs
# 6213             finely chopped fresh thyme         2 tbsp
# 6386                     150ml/5fl oz water
# 6393                     250ml/9oz red wine
# 6533                                 cashew         2 tbsp
# 6536     ½ x 400g/14oz tin chopped tomatoes
# 6844                                          10-12 cloves
# 7060                      mint leaves = 30g
# 61747
# 62637
# 63267                        ground almonds  2 tablespoons
# 63335
# 63814
# 63853
# 64019
# 64044
# 64117                         cloves minced       6 garlic
# 64179
# 64943
# 65037
#
# [43 rows x 258 columns]

# %%
recipes_df.iloc[63336,:]
# Out:
# Recipe_name       Cooking For Others: Non-Picnic Brunch
# 0_ingredient                 frisbee in the park brunch
# 0_quanitity
# 100_ingredient                            creme fraiche
# 100_quanitity                             2 tablespoons
# 101_ingredient
# 101_quanitity
# 102_ingredient
# 102_quanitity
# 103_quanitity
# 104_ingredient
# 104_quanitity
# 105_ingredient
# 105_quanitity
# 106_ingredient
# 106_quanitity
# 107_ingredient
# 107_quanitity
# 108_ingredient
# 108_quanitity
# 109_ingredient
# 109_quanitity
# 10_ingredient
# 10_quanitity                                 2 avocados
# 110_ingredient
# 110_quanitity
# 111_ingredient
# 111_quanitity
# 112_ingredient
# 112_quanitity
#                                   ...
# 87_ingredient
# 87_quanitity
# 88_ingredient                              low-fat milk
# 88_quanitity                                      1 cup
# 89_ingredient
# 89_quanitity
# 8_ingredient                                        ham
# 8_quanitity                                    8 slices
# 90_ingredient                             half and half
# 90_quanitity                                      1 cup
# 91_ingredient
# 91_quanitity
# 92_ingredient
# 92_quanitity                                      1 egg
# 93_ingredient
# 93_quanitity
# 94_ingredient                                      yolk
# 94_quanitity                                      1 egg
# 95_ingredient
# 95_quanitity
# 96_ingredient                                     sugar
# 96_quanitity                              6 tablespoons
# 97_ingredient
# 97_quanitity
# 98_ingredient                           vanilla extract
# 98_quanitity                                 1 teaspoon
# 99_ingredient
# 99_quanitity
# 9_ingredient
# 9_quanitity
# Name: 63336, Length: 258, dtype: object

# %%
# Out:
#                                                            0_ingredient  \
# Drop Biscuits and Sausage Gravy                                biscuits
# Hot Roast Beef Sandwiches           dinner rolls or small sandwich buns
# Morrocan Carrot and Chickpea Salad                            dressing:
# Mixed Berry Shortcake                                          biscuits
# Pomegranate Yogurt Bowl                                  for each bowl:
#
#                                    0_quanitity     10_ingredient  \
# Drop Biscuits and Sausage Gravy                    seasoned salt
# Hot Roast Beef Sandwiches             12 whole
# Morrocan Carrot and Chickpea Salad              fresh mint, torn
# Mixed Berry Shortcake                                      sugar
# Pomegranate Yogurt Bowl
#
#                                     10_quanitity  \
# Drop Biscuits and Sausage Gravy     1/2 teaspoon
# Hot Roast Beef Sandwiches
# Morrocan Carrot and Chickpea Salad  1/3 cup 30 g
# Mixed Berry Shortcake                    1/3 cup
# Pomegranate Yogurt Bowl
#
#                                                                         11_ingredient  \
# Drop Biscuits and Sausage Gravy                           black pepper, more to taste
# Hot Roast Beef Sandwiches
# Morrocan Carrot and Chickpea Salad  for serving: lots toasted almond slices, dried...
# Mixed Berry Shortcake                                                          orange
# Pomegranate Yogurt Bowl
#
#                                    11_quanitity       12_ingredient  \
# Drop Biscuits and Sausage Gravy     2 teaspoons
# Hot Roast Beef Sandwiches
# Morrocan Carrot and Chickpea Salad
# Mixed Berry Shortcake                   1 small  sweet yogurt cream
# Pomegranate Yogurt Bowl
#
#                                    12_quanitity       13_ingredient  \
# Drop Biscuits and Sausage Gravy
# Hot Roast Beef Sandwiches
# Morrocan Carrot and Chickpea Salad
# Mixed Berry Shortcake                            plain greek yogurt
# Pomegranate Yogurt Bowl
#
#                                    13_quanitity  ...  \
# Drop Biscuits and Sausage Gravy                  ...
# Hot Roast Beef Sandwiches                        ...
# Morrocan Carrot and Chickpea Salad               ...
# Mixed Berry Shortcake                 1 package  ...
# Pomegranate Yogurt Bowl                          ...
#
#                                                           5_ingredient  \
# Drop Biscuits and Sausage Gravy                              butermilk
# Hot Roast Beef Sandwiches                                  poppy seeds
# Morrocan Carrot and Chickpea Salad   fine sea salt, plus more to taste
# Mixed Berry Shortcake                     cold butter, cut into pieces
# Pomegranate Yogurt Bowl             sprinkling toasted sunflower seeds
#
#                                      5_quanitity  \
# Drop Biscuits and Sausage Gravy        1-1/4 cup
# Hot Roast Beef Sandwiches           1 tablespoon
# Morrocan Carrot and Chickpea Salad  1/2 teaspoon
# Mixed Berry Shortcake                1-1/2 stick
# Pomegranate Yogurt Bowl
#
#                                                                          6_ingredient  \
# Drop Biscuits and Sausage Gravy                                         sausage gravy
# Hot Roast Beef Sandwiches                                               spicy mustard
# Morrocan Carrot and Chickpea Salad                                     cayenne pepper
# Mixed Berry Shortcake                                                      buttermilk
# Pomegranate Yogurt Bowl             optional: whole pomegranate seeds or fresh/dri...
#
#                                      6_quanitity  \
# Drop Biscuits and Sausage Gravy
# Hot Roast Beef Sandwiches           1 tablespoon
# Morrocan Carrot and Chickpea Salad  1/8 teaspoon
# Mixed Berry Shortcake                  1-1/4 cup
# Pomegranate Yogurt Bowl
#
#                                                                          7_ingredient  \
# Drop Biscuits and Sausage Gravy                        breakfast sausage, hot or mild
# Hot Roast Beef Sandwiches           horseradish mayo or straight prepared horseradish
# Morrocan Carrot and Chickpea Salad  carrots, shredded on a box grater or sliced wh...
# Mixed Berry Shortcake                                                  almond extract
# Pomegranate Yogurt Bowl
#
#                                      7_quanitity            8_ingredient  \
# Drop Biscuits and Sausage Gravy          1 pound       all-purpose flour
# Hot Roast Beef Sandwiches           1 tablespoon  dash of worcestershire
# Morrocan Carrot and Chickpea Salad     10 ounces        cooked chickpeas
# Mixed Berry Shortcake               1/2 teaspoon                 berries
# Pomegranate Yogurt Bowl
#
#                                    8_quanitity  \
# Drop Biscuits and Sausage Gravy        1/3 cup
# Hot Roast Beef Sandwiches
# Morrocan Carrot and Chickpea Salad      2 cups
# Mixed Berry Shortcake
# Pomegranate Yogurt Bowl
#
#                                                                          9_ingredient  \
# Drop Biscuits and Sausage Gravy                                            whole milk
# Hot Roast Beef Sandwiches           optional dressing ingredients: sriracha, hot s...
# Morrocan Carrot and Chickpea Salad   dried pluots, plums, or dates cut into chickp...
# Mixed Berry Shortcake                        mixed berries and/or sliced strawberries
# Pomegranate Yogurt Bowl
#
#                                       9_quanitity
# Drop Biscuits and Sausage Gravy            4 cups
# Hot Roast Beef Sandwiches
# Morrocan Carrot and Chickpea Salad  2/3 cup 100 g
# Mixed Berry Shortcake                     2 pints
# Pomegranate Yogurt Bowl
#
# [5 rows x 34 columns]

# %%
# Out:
# '1 hen 2 chickens'
